# %% [markdown]
# # 划分训练集和测试集
#
# 同济子豪兄 https://space.bilibili.com/1900783
#
# 代码运行[云GPU平台](https://featurize.cn/?s=d7ce99f842414bfcaea5662a97581bd1)
#
# 2022-7-22

# %% [markdown]
# ## 导入工具包

# %%
import os
import shutil
import random
import pandas as pd

# %%
# 解压
# !unzip dataset_full.zip >> /dev/null
# Out:
# dataset_full/angry/愤怒0.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ0.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒1.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ1.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒100.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ100.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒102.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ102.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒106.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ106.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒107.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ107.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒109.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ109.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒117.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ117.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒12.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ12.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒125.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ125.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒126.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ126.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒128.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ128.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒13.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ13.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒130.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ130.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒132.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ132.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒133.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ133.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒134.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ134.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒135.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ135.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒136.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ136.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒137.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ137.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒138.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ138.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒139.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ139.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒14.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ14.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒140.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ140.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒141.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ141.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒144.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ144.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒147.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ147.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒148.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ148.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒149.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ149.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒15.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ15.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒151.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ151.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒152.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ152.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒153.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ153.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒154.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ154.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒155.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ155.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒156.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ156.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒157.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ157.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒158.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ158.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒159.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ159.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒16.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ16.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒160.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ160.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒161.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ161.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒162.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ162.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒163.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ163.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒164.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ164.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒165.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ165.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒166.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ166.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒167.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ167.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒169.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ169.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒17.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ17.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒170.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ170.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒171.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ171.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒172.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ172.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒173.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ173.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒174.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ174.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒175.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ175.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒176.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ176.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒177.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ177.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒179.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ179.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒18.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ18.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒180.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ180.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒181.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ181.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒182.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ182.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒183.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ183.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒184.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ184.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒186.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ186.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒188.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ188.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒189.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ189.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒19.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ19.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒190.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ190.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒191.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ191.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒194.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ194.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒195.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ195.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒196.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ196.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒197.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ197.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒198.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ198.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒199.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ199.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒2.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ2.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒20.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ20.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒200.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ200.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒201.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ201.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒204.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ204.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒205.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ205.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒209.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ209.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒21.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ21.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒210.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ210.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒212.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ212.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒213.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ213.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒214.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ214.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒215.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ215.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒216.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ216.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒219.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ219.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒22.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ22.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒220.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ220.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒221.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ221.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒222.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ222.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒223.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ223.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒224.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ224.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒225.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ225.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒226.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ226.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒227.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ227.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒228.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ228.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒23.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ23.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒230.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ230.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒231.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ231.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒232.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ232.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒233.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ233.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒234.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ234.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒235.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ235.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒237.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ237.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒238.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ238.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒239.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ239.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒24.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ24.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒240.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ240.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒242.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ242.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒243.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ243.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒244.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ244.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒245.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ245.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒246.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ246.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒247.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ247.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒249.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ249.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒25.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ25.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒250.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ250.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒252.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ252.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒253.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ253.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒254.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ254.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒255.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ255.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒256.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ256.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒257.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ257.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒258.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ258.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒259.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ259.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒26.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ26.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒260.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ260.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒261.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ261.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒262.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ262.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒265.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ265.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒266.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ266.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒267.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ267.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒268.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ268.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒269.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ269.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒27.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ27.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒271.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ271.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒273.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ273.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒274.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ274.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒275.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ275.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒279.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ279.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒28.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ28.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒280.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ280.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒281.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ281.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒282.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ282.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒283.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ283.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒285.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ285.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒287.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ287.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒29.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ29.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒290.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ290.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒293.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ293.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒294.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ294.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒295.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ295.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒297.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ297.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒298.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ298.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒299.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ299.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒3.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ3.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒30.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ30.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒304.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ304.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒305.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ305.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒306.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ306.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒307.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ307.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒308.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ308.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒309.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ309.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒31.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ31.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒310.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ310.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒312.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ312.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒314.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ314.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒315.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ315.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒316.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ316.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒318.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ318.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒32.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ32.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒321.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ321.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒322.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ322.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒324.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ324.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒325.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ325.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒326.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ326.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒327.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ327.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒329.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ329.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒33.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ33.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒330.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ330.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒331.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ331.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒335.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ335.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒336.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ336.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒34.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ34.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒342.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ342.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒344.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ344.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒345.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ345.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒349.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ349.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒35.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ35.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒351.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ351.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒352.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ352.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒354.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ354.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒356.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ356.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒36.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ36.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒361.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ361.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒363.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ363.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒364.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ364.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒365.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ365.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒369.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ369.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒37.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ37.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒372.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ372.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒373.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ373.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒377.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ377.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒379.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ379.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒38.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ38.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒380.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ380.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒383.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ383.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒384.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ384.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒39.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ39.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒390.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ390.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒392.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ392.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒393.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ393.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒397.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ397.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒398.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ398.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒4.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ4.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒40.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ40.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒405.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ405.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒41.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ41.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒410.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ410.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒411.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ411.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒412.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ412.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒414.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ414.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒416.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ416.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒418.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ418.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒42.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ42.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒424.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ424.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒426.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ426.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒427.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ427.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒428.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ428.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒429.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ429.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒43.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ43.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒430.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ430.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒431.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ431.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒432.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ432.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒433.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ433.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒44.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ44.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒443.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ443.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒444.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ444.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒447.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ447.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒448.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ448.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒449.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ449.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒450.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ450.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒454.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ454.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒455.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ455.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒456.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ456.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒457.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ457.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒459.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ459.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒46.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ46.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒464.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ464.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒467.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ467.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒469.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ469.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒47.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ47.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒472.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ472.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒477.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ477.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒479.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ479.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒48.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ48.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒484.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ484.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒485.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ485.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒49.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ49.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒493.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ493.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒494.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ494.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒496.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ496.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒5.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ5.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒50.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ50.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒51.jpeg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ51.jpeg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒53.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ53.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒54.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ54.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒55.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ55.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒56.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ56.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒58.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ58.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒6.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ6.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒60.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ60.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒61.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ61.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒62.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ62.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒63.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ63.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒64.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ64.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒65.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ65.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒67.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ67.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒68.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ68.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒69.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ69.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒7.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ7.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒72.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ72.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒76.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ76.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒77.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ77.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒79.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ79.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒8.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ8.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒80.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ80.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒82.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ82.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒83.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ83.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒84.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ84.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒85.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ85.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒86.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ86.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒87.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ87.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒88.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ88.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒89.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ89.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒9.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ9.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒91.png:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ91.png),
#          continuing with "central" filename version
# dataset_full/angry/愤怒92.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ92.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒93.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ93.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒94.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ94.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒95.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ95.jpg),
#          continuing with "central" filename version
# dataset_full/angry/愤怒98.jpg:  mismatching "local" filename (dataset_full/angry/цДдцАТяБЬ98.jpg),
#          continuing with "central" filename version
# dataset_full/happy/开心1.jpg:  mismatching "local" filename (dataset_full/happy/х╝Ах┐ГяБЬ1.jpg),
#          continuing with "central" filename version
# dataset_full/happy/开心104.jpg:  mismatching "local" filename (dataset_full/happy/х╝Ах┐ГяБЬ104.jpg),
#          continuing with "central" filename version
# dataset_full/happy/开心105.jpg:  mismatching "local" filename (dataset_full/happy/х╝Ах┐ГяБЬ105.jpg),
#          continuing with "central" filename version
# dataset_full/happy/开心106.jpg:  mismatching "local" filename (dataset_full/happy/х╝Ах┐ГяБЬ106.jpg),
#          continuing with "central" filename version
# dataset_full/happy/开心109.jpg:  mismatching "local" filename (dataset_full/happy/х╝Ах┐ГяБЬ109.jpg),
#          continuing with "central" filename version
# dataset_full/happy/开心111.jpg:  mismatching "local" filename (dataset_full/happy/х╝Ах┐ГяБЬ111.jpg),
#          continuing with "central" filename version
# dataset_full/happy/开心112.jpg:  mismatching "local" filename (dataset_full/happy/х╝Ах┐ГяБЬ112.jpg),
#          continuing with "central" filename version
# dataset_full/happy/开心113.jpg:  mismatching "local" filename (dataset_full/happy/х╝Ах┐ГяБЬ113.jpg),
#          continuing with "central" filename version
# dataset_full/happy/开心115.jpg:  mismatching "local" filename (dataset_full/happy/х╝Ах┐ГяБЬ115.jpg),
# ...
# dataset_full/scared/恐惧142.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ142.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧150.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ150.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧152.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ152.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧153.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ153.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧155.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ155.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧157.jpeg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ157.jpeg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧158.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ158.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧160.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ160.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧161.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ161.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧163.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ163.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧164.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ164.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧165.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ165.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧166.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ166.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧169.png:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ169.png),
#          continuing with "central" filename version
# dataset_full/scared/恐惧17.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ17.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧170.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ170.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧171.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ171.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧172.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ172.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧173.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ173.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧174.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ174.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧175.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ175.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧177.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ177.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧178.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ178.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧183.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ183.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧184.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ184.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧189.png:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ189.png),
#          continuing with "central" filename version
# dataset_full/scared/恐惧190.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ190.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧191.jpeg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ191.jpeg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧192.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ192.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧193.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ193.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧195.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ195.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧2.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ2.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧20.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ20.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧201.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ201.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧207.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ207.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧208.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ208.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧209.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ209.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧210.png:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ210.png),
#          continuing with "central" filename version
# dataset_full/scared/恐惧214.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ214.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧218.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ218.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧22.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ22.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧221.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ221.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧222.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ222.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧223.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ223.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧224.jpeg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ224.jpeg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧231.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ231.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧233.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ233.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧234.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ234.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧235.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ235.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧237.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ237.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧243.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ243.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧245.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ245.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧249.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ249.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧252.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ252.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧256.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ256.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧259.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ259.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧263.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ263.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧272.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ272.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧274.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ274.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧275.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ275.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧286.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ286.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧287.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ287.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧292.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ292.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧300.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ300.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧303.jpeg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ303.jpeg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧307.jpeg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ307.jpeg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧322.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ322.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧323.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ323.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧326.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ326.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧33.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ33.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧34.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ34.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧344.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ344.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧349.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ349.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧35.jpeg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ35.jpeg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧351.jpeg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ351.jpeg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧355.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ355.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧356.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ356.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧36.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ36.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧364.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ364.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧37.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ37.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧38.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ38.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧39.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ39.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧40.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ40.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧42.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ42.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧422.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ422.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧43.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ43.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧438.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ438.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧44.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ44.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧45.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ45.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧484.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ484.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧485.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ485.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧54.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ54.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧60.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ60.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧61.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ61.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧62.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ62.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧66.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ66.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧7.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ7.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧77.jpeg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ77.jpeg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧82.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ82.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧86.jpeg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ86.jpeg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧9.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ9.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧97.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ97.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧98.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ98.jpg),
#          continuing with "central" filename version
# dataset_full/scared/恐惧99.jpg:  mismatching "local" filename (dataset_full/scared/цБРцГзяБЬ99.jpg),
#          continuing with "central" filename version

# %% [markdown]
# ## 获得所有类别名称

# %%
# 指定数据集路径
dataset_path = 'dataset'

# %%
dataset_name = dataset_path.split('_')[0]
print('数据集', dataset_name)
# Out:
# 数据集 dataset

# %%
classes = os.listdir(dataset_path)

# %%
len(classes)
# Out:
# 5

# %%
classes
# Out:
# ['puzzled', 'scared', 'sad', 'happy', 'angry']

# %% [markdown]
# ## 创建训练集文件夹和测试集文件夹

# %%
# 创建 train 文件夹
os.mkdir(os.path.join(dataset_path, 'train'))

# 创建 test 文件夹
os.mkdir(os.path.join(dataset_path, 'val'))

# 在 train 和 test 文件夹中创建各类别子文件夹
for fruit in classes:
    os.mkdir(os.path.join(dataset_path, 'train', fruit))
    os.mkdir(os.path.join(dataset_path, 'val', fruit))

# %% [markdown]
# ## 划分训练集、测试集，移动文件

# %%
test_frac = 0.2  # 测试集比例
random.seed(123) # 随机数种子，便于复现

# %%
df = pd.DataFrame()

print('{:^18} {:^18} {:^18}'.format('类别', '训练集数据个数', '测试集数据个数'))

for fruit in classes: # 遍历每个类别

    # 读取该类别的所有图像文件名
    old_dir = os.path.join(dataset_path, fruit)
    images_filename = os.listdir(old_dir)
    random.shuffle(images_filename) # 随机打乱

    # 划分训练集和测试集
    testset_numer = int(len(images_filename) * test_frac) # 测试集图像个数
    testset_images = images_filename[:testset_numer]      # 获取拟移动至 test 目录的测试集图像文件名
    trainset_images = images_filename[testset_numer:]     # 获取拟移动至 train 目录的训练集图像文件名

    # 移动图像至 test 目录
    for image in testset_images:
        old_img_path = os.path.join(dataset_path, fruit, image)         # 获取原始文件路径
        new_test_path = os.path.join(dataset_path, 'val', fruit, image) # 获取 test 目录的新文件路径
        shutil.move(old_img_path, new_test_path) # 移动文件

    # 移动图像至 train 目录
    for image in trainset_images:
        old_img_path = os.path.join(dataset_path, fruit, image)           # 获取原始文件路径
        new_train_path = os.path.join(dataset_path, 'train', fruit, image) # 获取 train 目录的新文件路径
        shutil.move(old_img_path, new_train_path) # 移动文件
    
    # 删除旧文件夹
    assert len(os.listdir(old_dir)) == 0 # 确保旧文件夹中的所有图像都被移动走
    shutil.rmtree(old_dir) # 删除文件夹
    
    # 工整地输出每一类别的数据个数
    print('{:^18} {:^18} {:^18}'.format(fruit, len(trainset_images), len(testset_images)))
    
    # 保存到表格中
    df = df.append({'class':fruit, 'trainset':len(trainset_images), 'testset':len(testset_images)}, ignore_index=True)

# 重命名数据集文件夹
shutil.move(dataset_path, dataset_name+'_split')

# 数据集各类别数量统计表格，导出为 csv 文件
df['total'] = df['trainset'] + df['testset']
df.to_csv('数据量统计.csv', index=False)
# Out:
#         类别              训练集数据个数            测试集数据个数
#      puzzled               56                 13
#       scared              100                 24
#        sad                 60                 14
#       happy               349                 87
#       angry               247                 61

# %%
df
# Out:
#      class  trainset  testset  total
# 0  puzzled      56.0     13.0   69.0
# 1   scared     100.0     24.0  124.0
# 2      sad      60.0     14.0   74.0
# 3    happy     349.0     87.0  436.0
# 4    angry     247.0     61.0  308.0

# %% [markdown]
# ## 查看文件目录结构

# %%
# !sudo snap install tree
# Out:
# error: cannot install "tree": Post https://api.snapcraft.io/v2/snaps/refresh:
#        read tcp 172.16.125.125:53150->172.16.0.13:5848: read: connection reset
#        by peer

# %%
# !tree fruit81_split -L 2
# Out:
# fruit81_split [error opening dir]
#
# 0 directories, 0 files
